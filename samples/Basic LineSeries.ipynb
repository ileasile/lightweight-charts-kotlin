// %%
@file:Repository("*mavenLocal")

// %%
@file:DependsOn("ru.ileasile:lightweight-charts-kotlin:1.0-SNAPSHOT")

// %%
val chart = ChartImpl(ChartOptions(600, 400))
val lineSeries = LineSeries()
lineSeries.setData(listOf(
        LineDataItem(java.util.Date(118, 10, 22), 51.65),
    LineDataItem(java.util.Date(118, 10, 23), 51.56),
    LineDataItem(java.util.Date(118, 10, 24), 50.19),
    LineDataItem(java.util.Date(118, 10, 25), 51.86),
    LineDataItem(java.util.Date(118, 10, 26), 51.25),
    LineDataItem(java.util.Date(118, 10, 29), 52.23),
    LineDataItem(java.util.Date(118, 10, 30), 52.69),
    LineDataItem(java.util.Date(118, 10, 31), 53.23),
    LineDataItem(java.util.Date(118, 11, 1), 53.56),
    LineDataItem(java.util.Date(118, 11, 2), 53.61),
    LineDataItem(java.util.Date(118, 11, 5), 53.66),
    LineDataItem(java.util.Date(118, 11, 6), 53.55),
    LineDataItem(java.util.Date(118, 11, 7), 53.58),
    LineDataItem(java.util.Date(118, 11, 8), 53.16),
    LineDataItem(java.util.Date(118, 11, 9), 53.04),
    LineDataItem(java.util.Date(118, 11, 12), 52.35),
    LineDataItem(java.util.Date(118, 11, 13), 52.74),
    LineDataItem(java.util.Date(118, 11, 14), 52.15),
    LineDataItem(java.util.Date(118, 11, 15), 52.82),
    LineDataItem(java.util.Date(118, 11, 16), 52.94),
    LineDataItem(java.util.Date(118, 11, 19), 53.32),
    LineDataItem(java.util.Date(118, 11, 20), 52.54),
    LineDataItem(java.util.Date(118, 11, 21), 52.43),
    LineDataItem(java.util.Date(118, 11, 23), 51.83),
    LineDataItem(java.util.Date(118, 11, 26), 52.88),
    LineDataItem(java.util.Date(118, 11, 27), 53.19),
    LineDataItem(java.util.Date(118, 11, 28), 54.35),
    LineDataItem(java.util.Date(118, 11, 29), 54.04),
    LineDataItem(java.util.Date(118, 11, 30), 54.28),
    LineDataItem(java.util.Date(118, 12, 3), 54.24),
    LineDataItem(java.util.Date(118, 12, 4), 51.78),
    LineDataItem(java.util.Date(118, 12, 6), 51.09),
    LineDataItem(java.util.Date(118, 12, 7), 50.26),
    LineDataItem(java.util.Date(118, 12, 10), 48.80),
    LineDataItem(java.util.Date(118, 12, 11), 47.76),
    LineDataItem(java.util.Date(118, 12, 12), 47.74),
    LineDataItem(java.util.Date(118, 12, 13), 47.03),
    LineDataItem(java.util.Date(118, 12, 14), 46.54),
    LineDataItem(java.util.Date(118, 12, 17), 46.61),
    LineDataItem(java.util.Date(118, 12, 18), 46.52),
    LineDataItem(java.util.Date(118, 12, 19), 45.67),
    LineDataItem(java.util.Date(118, 12, 20), 46.04),
    LineDataItem(java.util.Date(118, 12, 21), 45.12),
    LineDataItem(java.util.Date(118, 12, 24), 43.60),
    LineDataItem(java.util.Date(118, 12, 26), 45.59),
    LineDataItem(java.util.Date(118, 12, 27), 45.53),
    LineDataItem(java.util.Date(118, 12, 28), 45.78),
    LineDataItem(java.util.Date(118, 12, 31), 46.08),
    LineDataItem(java.util.Date(119, 1, 2), 46.94),
    LineDataItem(java.util.Date(119, 1, 3), 46.57),
    LineDataItem(java.util.Date(119, 1, 4), 47.95),
    LineDataItem(java.util.Date(119, 1, 7), 47.64),
    LineDataItem(java.util.Date(119, 1, 8), 47.54),
    LineDataItem(java.util.Date(119, 1, 9), 47.80),
    LineDataItem(java.util.Date(119, 1, 10), 47.75),
    LineDataItem(java.util.Date(119, 1, 11), 47.87),
    LineDataItem(java.util.Date(119, 1, 14), 48.42),
    LineDataItem(java.util.Date(119, 1, 15), 47.67),
    LineDataItem(java.util.Date(119, 1, 16), 48.94),
    LineDataItem(java.util.Date(119, 1, 17), 49.23),
    LineDataItem(java.util.Date(119, 1, 18), 50.01),
    LineDataItem(java.util.Date(119, 1, 22), 49.86),
    LineDataItem(java.util.Date(119, 1, 23), 50.12),
    LineDataItem(java.util.Date(119, 1, 24), 49.98),
    LineDataItem(java.util.Date(119, 1, 25), 50.13),
    LineDataItem(java.util.Date(119, 1, 28), 49.82),
    LineDataItem(java.util.Date(119, 1, 29), 49.85),
    LineDataItem(java.util.Date(119, 1, 30), 50.09),
    LineDataItem(java.util.Date(119, 1, 31), 48.91),
    LineDataItem(java.util.Date(119, 2, 1), 48.91),
    LineDataItem(java.util.Date(119, 2, 4), 49.06),
    LineDataItem(java.util.Date(119, 2, 5), 49.27),
    LineDataItem(java.util.Date(119, 2, 6), 49.22),
    LineDataItem(java.util.Date(119, 2, 7), 48.08),
    LineDataItem(java.util.Date(119, 2, 8), 47.65),
    LineDataItem(java.util.Date(119, 2, 11), 47.65),
    LineDataItem(java.util.Date(119, 2, 12), 49.05),
    LineDataItem(java.util.Date(119, 2, 13), 49.02),
    LineDataItem(java.util.Date(119, 2, 14), 48.52),
    LineDataItem(java.util.Date(119, 2, 15), 49.22),
    LineDataItem(java.util.Date(119, 2, 19), 49.38),
    LineDataItem(java.util.Date(119, 2, 20), 49.81),
    LineDataItem(java.util.Date(119, 2, 21), 49.56),
    LineDataItem(java.util.Date(119, 2, 22), 49.02),
    LineDataItem(java.util.Date(119, 2, 25), 49.66),
    LineDataItem(java.util.Date(119, 2, 26), 49.59),
    LineDataItem(java.util.Date(119, 2, 27), 49.90),
    LineDataItem(java.util.Date(119, 2, 28), 49.89),
    LineDataItem(java.util.Date(119, 3, 1), 50.03),
    LineDataItem(java.util.Date(119, 3, 4), 50.11),
    LineDataItem(java.util.Date(119, 3, 5), 49.89),
    LineDataItem(java.util.Date(119, 3, 6), 49.82),
    LineDataItem(java.util.Date(119, 3, 7), 49.68),
    LineDataItem(java.util.Date(119, 3, 8), 49.80),
    LineDataItem(java.util.Date(119, 3, 11), 49.76),
    LineDataItem(java.util.Date(119, 3, 12), 49.65),
    LineDataItem(java.util.Date(119, 3, 13), 49.92),
    LineDataItem(java.util.Date(119, 3, 14), 50.35),
    LineDataItem(java.util.Date(119, 3, 15), 50.66),
    LineDataItem(java.util.Date(119, 3, 18), 51.73),
    LineDataItem(java.util.Date(119, 3, 19), 51.41),
    LineDataItem(java.util.Date(119, 3, 20), 50.40),
    LineDataItem(java.util.Date(119, 3, 21), 49.86),
    LineDataItem(java.util.Date(119, 3, 22), 48.31),
    LineDataItem(java.util.Date(119, 3, 25), 48.08),
    LineDataItem(java.util.Date(119, 3, 26), 49.01),
    LineDataItem(java.util.Date(119, 3, 27), 48.77),
    LineDataItem(java.util.Date(119, 3, 28), 49.09),
    LineDataItem(java.util.Date(119, 3, 29), 48.32),
    LineDataItem(java.util.Date(119, 4, 1), 48.81),
    LineDataItem(java.util.Date(119, 4, 2), 48.21),
    LineDataItem(java.util.Date(119, 4, 3), 48.86),
    LineDataItem(java.util.Date(119, 4, 4), 49.17),
    LineDataItem(java.util.Date(119, 4, 5), 48.78),
    LineDataItem(java.util.Date(119, 4, 8), 48.88),
    LineDataItem(java.util.Date(119, 4, 9), 48.14),
    LineDataItem(java.util.Date(119, 4, 10), 47.79),
    LineDataItem(java.util.Date(119, 4, 11), 47.74),
    LineDataItem(java.util.Date(119, 4, 12), 46.49),
    LineDataItem(java.util.Date(119, 4, 15), 46.77),
    LineDataItem(java.util.Date(119, 4, 16), 47.65),
    LineDataItem(java.util.Date(119, 4, 17), 47.55),
    LineDataItem(java.util.Date(119, 4, 18), 47.58),
    LineDataItem(java.util.Date(119, 4, 22), 47.26),
    LineDataItem(java.util.Date(119, 4, 23), 47.35),
    LineDataItem(java.util.Date(119, 4, 24), 47.48),
    LineDataItem(java.util.Date(119, 4, 25), 47.51),
    LineDataItem(java.util.Date(119, 4, 26), 47.96),
    LineDataItem(java.util.Date(119, 4, 29), 48.27),
    LineDataItem(java.util.Date(119, 4, 30), 48.41),
    LineDataItem(java.util.Date(119, 5, 1), 48.23),
    LineDataItem(java.util.Date(119, 5, 2), 48.30),
    LineDataItem(java.util.Date(119, 5, 3), 48.65),
    LineDataItem(java.util.Date(119, 5, 6), 48.43),
    LineDataItem(java.util.Date(119, 5, 7), 47.17),
    LineDataItem(java.util.Date(119, 5, 8), 47.00),
    LineDataItem(java.util.Date(119, 5, 9), 46.74),
    LineDataItem(java.util.Date(119, 5, 10), 47.15),
    LineDataItem(java.util.Date(119, 5, 13), 46.33),
    LineDataItem(java.util.Date(119, 5, 14), 46.49),
    LineDataItem(java.util.Date(119, 5, 15), 45.84),
    LineDataItem(java.util.Date(119, 5, 16), 45.90),
    LineDataItem(java.util.Date(119, 5, 17), 45.70),
    LineDataItem(java.util.Date(119, 5, 20), 45.45),
    LineDataItem(java.util.Date(119, 5, 21), 46.33),
    LineDataItem(java.util.Date(119, 5, 22), 46.10),
    LineDataItem(java.util.Date(119, 5, 23), 45.56),
    LineDataItem(java.util.Date(119, 5, 24), 46.17),
    LineDataItem(java.util.Date(119, 5, 28), 46.01),
))
chart.addSeries(lineSeries)
chart
// Out:
// <div id="chart_elem_9"></div>
// <script type="text/javascript">
// call_TVLightweightCharts(function(){
// var div_chart_elem_9 = document.getElementById("chart_elem_9");
// var chart_10 = LightweightCharts.createChart(div_chart_elem_9, {"width":600,"height":400});
// var series_11 = chart_10.addLineSeries();
// ...
